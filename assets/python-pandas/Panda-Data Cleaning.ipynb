# %%
# DATA CLEANING IN PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\Electric_Vehicle_Population_Data.csv")
df
# Out:
#     VIN (1-10)     County               City State  Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima    WA         NaN       FIAT
# 1   WP0AB2Y16L       King             Auburn    WA      2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle    WA         NaN      TESLA
# 3   5YJYGDEF5L       King            Seattle    WA      2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia    WA      2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia    WA      2020.0  CHEVROLET
# 6          NaN     Yakima              Moxee    WA      2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island    WA      2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia    WA      2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle    WA      2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater    WA      2025.0     NISSAN
# 11  5YJYGDEE3L     Kitsap            Poulsbo    WA      2020.0      TESLA
# ...

# %%
#inspecting shape, column name and datatypes(.shape(, .info())
#having a feel of the data by previewing the rows(.head(), .tail()) or .describe(include='all')
#checking for data quality =>missing values(.isnull().sum())
#checking for duplicate(.duplicate(.sum()))
#explore distribution
    #=>value count(df['col'].value_counts())
    #=>histograms (df['col'].hist())
#correlation
    #=>correlation(df.corr(numeric_only= TTrue))
    #=>grouped summaries(df.groupby('col')['rarget'].mean())
#slice and dlicense
    #=>filtering(df[df['age'] > 40])
    #=>sorting (df.sort_values('salary', ascending = False))
#Visual Sanity Check
    #=>boxplots for outliers(df.boxplot(column='salary'))
    #=>scatter plots(df.plot.scatter(x='age', y='salary'))

# %%
#checking for duplicate
#df.duplicate().sum()

#removing duplicate
#df.drop_duplicate()

# %%
#removing %col

df = df.drop(columns= 'State')
df
# Out:
#     VIN (1-10)     County               City  Model Year       Make    Model  \
# 0   3C3CFFGE1G     Yakima             Yakima         NaN       FIAT      500
# 1   WP0AB2Y16L       King             Auburn      2020.0    PORSCHE   TAYCAN
# 2   5YJ3E1EB2J       King            Seattle         NaN      TESLA  MODEL 3
# 3   5YJYGDEF5L       King            Seattle      2020.0      TESLA  MODEL Y
# 4   5YJXCBE22J   Thurston            Olympia      2018.0      TESLA  MODEL X
# 5   1G1FZ6S00L   Thurston            Olympia      2020.0  CHEVROLET  BOLT EV
# 6          NaN     Yakima              Moxee      2022.0      TESLA  MODEL 3
# 7   5YJSA1E29J     Kitsap  Bainbridge Island      2018.0      TESLA  MODEL S
# 8   JN1AZ0CPXB   Thurston            Olympia      2011.0     NISSAN     LEAF
# 9   KNDCM3LD1J       King            Seattle      2018.0        KIA      NaN
# 10  1N4CZ1CV0S   Thurston           Tumwater      2025.0     NISSAN     LEAF
# ...

# %%
#to clean a col, you strip()

#from the right =>df['City'].str.strip ('/')
#from the left =>df['City'].str.strip ('...')
#stripping all noted errors =>df['City'].str.strip ('123,_/')

df['City'].str.strip ()
# Out:
# 0                Yakima
# 1                Auburn
# 2               Seattle
# 3               Seattle
# 4               Olympia
# 5               Olympia
# 6                 Moxee
# 7     Bainbridge Island
# 8               Olympia
# 9               Seattle
# 10             Tumwater
# 11              Poulsbo
# 12    Bainbridge Island
# 13              Olympia
# 14    Bainbridge Island
# 15              Olympia
# 16             Kingston
# 17              Seattle
# 18                Lacey
# 19             Kirkland
# 20               Monroe
# 21              Everett
# 22              Seattle
# 23            Bremerton
# 24                 Yelm
# 25              Rainier
# 26             Kingston
# 27               Yakima
# 28              Rainier
# Name: City, dtype: object

# %%
#df['DOL Vehicle ID'].str.replace('[a-zA-Z0-9')', '')

df['DOL Vehicle ID'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 29 entries, 0 to 28
# Series name: DOL Vehicle ID
# Non-Null Count  Dtype
# --------------  -----
# 29 non-null     int64
# dtypes: int64(1)
# memory usage: 364.0 bytes

# %%
#df['DOL Vehicle ID'].apply(lambda x : x[0:3] + '-' + x[3:6]+ '-' +x[6:9])
#had an error xoz the x isnt a strong. means values in the dol_veh are none iint

#had to convert it to a str.
df['DOL Vehicle ID'] = df['DOL Vehicle ID'].astype(str)

print(df['DOL Vehicle ID'].dtype)
# Out:
# object

# %%
df['DOL Vehicle ID'] = df['DOL Vehicle ID'].apply(lambda x : x[0:3] + '-' + x[3:6]+ '-' +x[6:9])
df['DOL Vehicle ID']
# Out:
# 0     180-778-377
# 1     277-717-723
# 2     475-865-722
# 3     108-837-249
# 4     259-851-259
# 5     255-186-389
# 6     211-877-725
# 7     112-582-634
# 8     144-417-262
# 9     333-286-894
# 10    280-202-765
# 11    109-705-683
# 12    269-429-793
# 13    265-811-318
# 14    179-002-876
# 15    259-002-390
# 16    252-689-629
# 17    284-075-102
# 18      221-154-1
# 19      853-476-0
# 20    276-917-441
# 21    346-738-318
# 22    113-297-257
# 23    179-470-693
# 24    154-666-788
# 25    261-605-466
# 26    215-241-162
# 27    269-419-090
# 28    259-188-835
# Name: DOL Vehicle ID, dtype: object

# %%
df
# Out:
#     VIN (1-10)     County               City State  Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima    WA         NaN       FIAT
# 1   WP0AB2Y16L       King             Auburn    WA      2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle    WA         NaN      TESLA
# 3   5YJYGDEF5L       King            Seattle    WA      2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia    WA      2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia    WA      2020.0  CHEVROLET
# 6          NaN     Yakima              Moxee    WA      2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island    WA      2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia    WA      2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle    WA      2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater    WA      2025.0     NISSAN
# 11  5YJYGDEE3L     Kitsap            Poulsbo    WA      2020.0      TESLA
# ...

# %%
#SPLIT()

df[['Electric Vehicle Type', 'EVT_Abb']]= df['Electric Vehicle Type'].str.split('(', n=1, expand=True)
df
# Out:
#     VIN (1-10)     County               City State  Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima    WA         NaN       FIAT
# 1   WP0AB2Y16L       King             Auburn    WA      2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle    WA         NaN      TESLA
# 3   5YJYGDEF5L       King            Seattle    WA      2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia    WA      2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia    WA      2020.0  CHEVROLET
# 6          NaN     Yakima              Moxee    WA      2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island    WA      2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia    WA      2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle    WA      2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater    WA      2025.0     NISSAN
# 11  5YJYGDEE3L     Kitsap            Poulsbo    WA      2020.0      TESLA
# ...

# %%
df['EVT_Abb'] = df['EVT_Abb'].str.rstrip(')')
df
# Out:
#     VIN (1-10)     County               City     State  Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima  West Ash         NaN       FIAT
# 1   WP0AB2Y16L       King             Auburn  West Ash      2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle  West Ash         NaN      TESLA
# 3   5YJYGDEF5L       King            Seattle  West Ash      2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia  West Ash      2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia  West Ash      2020.0  CHEVROLET
# 6          NaN     Yakima              Moxee  West Ash      2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island  West Ash      2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia  West Ash      2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle  West Ash      2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater  West Ash      2025.0     NISSAN
# ...

# %%
#Abbreviationabs

df['State'] = df['State'].str.replace('WA', 'West Ash')
df
# Out:
#     VIN (1-10)     County               City     State  Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima  West Ash         NaN       FIAT
# 1   WP0AB2Y16L       King             Auburn  West Ash      2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle  West Ash         NaN      TESLA
# 3   5YJYGDEF5L       King            Seattle  West Ash      2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia  West Ash      2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia  West Ash      2020.0  CHEVROLET
# 6          NaN     Yakima              Moxee  West Ash      2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island  West Ash      2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia  West Ash      2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle  West Ash      2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater  West Ash      2025.0     NISSAN
# ...

# %%
#Null Values

# %%
#df= df.replace('N/A','')
#df = df.replace('NaN','')

#fill none value cell with blanks
df = df.fillna('')
df
# Out:
#     VIN (1-10)     County               City     State Model Year       Make  \
# 0   3C3CFFGE1G     Yakima             Yakima  West Ash                  FIAT
# 1   WP0AB2Y16L       King             Auburn  West Ash     2020.0    PORSCHE
# 2   5YJ3E1EB2J       King            Seattle  West Ash                 TESLA
# 3   5YJYGDEF5L       King            Seattle  West Ash     2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia  West Ash     2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia  West Ash     2020.0  CHEVROLET
# 6                  Yakima              Moxee  West Ash     2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island  West Ash     2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia  West Ash     2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle  West Ash     2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater  West Ash     2025.0     NISSAN
# ...

# %%
#looping to drop blank row in 'model year' using the dataframe index 
#for x in df.index:
   # if df.loc[x, 'Model Year'] == fillna('')
   # df.drop(x, inplace= True)
#           OR
# df.dropna(subset="City")


df = df[df['Model Year'] != '']
df
# Out:
#     VIN (1-10)     County               City     State Model Year       Make  \
# 1   WP0AB2Y16L       King             Auburn  West Ash     2020.0    PORSCHE
# 3   5YJYGDEF5L       King            Seattle  West Ash     2020.0      TESLA
# 4   5YJXCBE22J   Thurston            Olympia  West Ash     2018.0      TESLA
# 5   1G1FZ6S00L   Thurston            Olympia  West Ash     2020.0  CHEVROLET
# 6                  Yakima              Moxee  West Ash     2022.0      TESLA
# 7   5YJSA1E29J     Kitsap  Bainbridge Island  West Ash     2018.0      TESLA
# 8   JN1AZ0CPXB   Thurston            Olympia  West Ash     2011.0     NISSAN
# 9   KNDCM3LD1J       King            Seattle  West Ash     2018.0        KIA
# 10  1N4CZ1CV0S   Thurston           Tumwater  West Ash     2025.0     NISSAN
# 11  5YJYGDEE3L     Kitsap            Poulsbo  West Ash     2020.0      TESLA
# 12                 Kitsap  Bainbridge Island  West Ash     2024.0       AUDI
# ...
