# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Seyy_'

# %%
os.chdir(r'C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python')
print(os.getcwd())
# Out:
# C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Seyy_\Downloads\Electric_Vehicle_Population_Data.csv")
df
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# 1       WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# 2       5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# 3       5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# 4       5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...            ...        ...         ...   ...          ...         ...
# 269668  5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# 269669  5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# 269670  5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# 269671  7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# 269672  JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Make    Model                   Electric Vehicle Type  \
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df1 = pd.read_csv(r"C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\employees.csv")
df1
# Out:
#    employee_id         name department   hire_date
# 0          101  Alice Smith      Sales  2020-03-15
# 1          102  Bob Johnson         HR  2019-07-22
# 2          103  Carol White         IT  2021-01-10
# 3          104  David Brown      Sales  2022-05-30

# %%
df2 = pd.read_csv(r"C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\salaries.csv")
df2
# Out:
#    employee_id  base_salary  bonus pay_grade
# 0          101        55000   5000         B
# 1          102        60000   4000         B
# 2          105        65000   6000         A
# 3          106        70000   7000         A

# %%
df3 = pd.merge(df1, df2, how = 'outer', on='employee_id')
df3
# Out:
#    employee_id         name department   hire_date  base_salary   bonus  \
# 0          101  Alice Smith      Sales  2020-03-15      55000.0  5000.0
# 1          102  Bob Johnson         HR  2019-07-22      60000.0  4000.0
# 2          103  Carol White         IT  2021-01-10          NaN     NaN
# 3          104  David Brown      Sales  2022-05-30          NaN     NaN
# 4          105          NaN        NaN         NaN      65000.0  6000.0
# 5          106          NaN        NaN         NaN      70000.0  7000.0
#
#   pay_grade
# 0         B
# 1         B
# 2       NaN
# 3       NaN
# 4         A
# 5         A

# %%
df3.plot()
# Out:
# <Axes: >

# %%
#using subplot()

df3.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
#adding title and axis labelling 

df3.plot(kind = 'line', title="Employee Details", xlabel = 'ranges', ylabel ='salary range')
# Out:
# <Axes: title={'center': 'Employee Details'}, xlabel='ranges', ylabel='salary range'>

# %%
#BAR

#df3.plot.bar()
#      or
df3.plot(kind= 'bar')
# Out:
# <Axes: >

# %%
#BAR with stacked bar

df3.plot.bar(stacked = True)
#      or
#df3.plot(kind= 'bar',stacked = True)
# Out:
# <Axes: >

# %%
#to have horizontal bars goes with   .barh

# %%
df3.plot.barh(stacked = True)
# Out:
# <Axes: >

# %%
# SCATTER PLOT()
#with scatter plot() needs the x and y axis assign to work

# %%
df3.plot.scatter(x= 'employee_id', y='base_salary', s = 80)
# Out:
# <Axes: xlabel='employee_id', ylabel='base_salary'>

# %%
#HIST

# %%
df3.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3.plot.hist(bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Boxplot

# %%
df3.boxplot()
# Out:
# <Axes: >

# %%
df3.boxplot(figsize=(10,4))
# Out:
# <Axes: >

# %%
df3.plot.pie(y='employee_id', figsize=(10,5))
# Out:
# <Axes: ylabel='employee_id'>
