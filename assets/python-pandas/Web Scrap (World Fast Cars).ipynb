# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_production_car_speed_records'

page = requests.get(url)

# %%
BeautifulSoup(page.text, 'html.parser')
# Out:
# C:\Users\Seyy_\AppData\Local\Temp\ipykernel_19820\2401231393.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   BeautifulSoup(page.text, 'html.parser')
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_production_car_speed_records'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of production car speed records - Wikipedia</title>
# ...

# %%
table = soup.find('table', class_='wikitable sortable')

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Year
# </th>
# <th>Make and model
# </th>
# <th>Top speed
# </th>
# <th>Engine
# </th>
# <th>Number built
# </th>
# <th>Comment
# </th></tr>
# <tr>
# <td>1894
# </td>
# <td><a href="/wiki/Benz_Velo" title="Benz Velo">Benz Velo</a>
# </td>
# <td>20 km/h (12 mph)<sup class="reference" id="cite_ref-3"><a href="#cite_note-3"><span class="cite-bracket">[</span>3<span class="cite-bracket">]</span></a></sup>
# </td>
# <td>1,045 cc (63.8 cu in) single-cylinder 1.1 kW (1.5 PS; 1.5 bhp)
# </td>
# <td>1,200
# </td>
# <td>First production car
# </td></tr>
# <tr>
# <td>1949
# </td>
# <td><a href="/wiki/Jaguar_XK120" title="Jaguar XK120">Jaguar XK120</a>
# </td>
# <td>200.5 km/h (124.6 mph)<sup class="reference" id="cite_ref-aw20121015_4-0"><a href="#cite_note-aw20121015-4"><span class="cite-bracket">[</span>4<span class="cite-bracket">]</span></a></sup>
# </td>
# <td>3,442 cc (210.0 cu in) inline-6 119 kW (162 PS; 160 hp)
# </td>
# ...

# %%
headers_title = table.find_all('th')

# %%
Header =[title.text.strip() for title in headers_title]

# %%
print(Header)
# Out:
# ['Year', 'Make and model', 'Top speed', 'Engine', 'Number built', 'Comment']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=Header)

# %%
row_data = table.find_all('tr')

# %%
for data in row_data[1:]:
    each_row_data = data.find_all('td')
    insert_data =[datas.text.strip() for datas in each_row_data]

    length = len(df)
    df.loc[length] = insert_data

# %%
df
# Out:
#     Year                   Make and model                   Top speed  \
# 0   1894                        Benz Velo         20 km/h (12 mph)[3]
# 1   1949                     Jaguar XK120   200.5 km/h (124.6 mph)[4]
# 2   1955             Mercedes-Benz 300 SL   242.5 km/h (150.7 mph)[7]
# 3   1959              Aston Martin DB4 GT   245.4 km/h (152.5 mph)[8]
# 4   1960       Aston Martin DB4 GT Zagato     247 km/h (153.5 mph)[9]
# 5   1963                 Iso Grifo GL 365      259 km/h (161 mph)[10]
# 6   1965              AC Cobra Mk III 427      266 km/h (165 mph)[12]
# 7   1967           Lamborghini Miura P400      275 km/h (171 mph)[13]
# 8   1968        Ferrari 365 GTB/4 Daytona      280 km/h (174 mph)[14]
# 9   1969          Lamborghini Miura P400S  288.6 km/h (179.3 mph)[15]
# 10  1982     Lamborghini Countach LP500 S      293 km/h (182 mph)[16]
# 11  1983                          Ruf BTR      305 km/h (190 mph)[17]
# ...

# %%
df.to_csv(r'C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\fast_cars_file.csv', index= False)
