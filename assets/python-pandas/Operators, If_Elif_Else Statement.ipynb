# %% [markdown]
# # comparison Operatorsabs

# %%
10 != 50
# Out:
# True

# %%
100 == 200
# Out:
# False

# %%
x = 'Vaniila'
y ='chocolate'

x != y
# Out:
# True

# %%
#LOGICAL OPERATORSabs

# %%
(10 > 50) and (50>10)
# Out:
# False

# %%
(10 > 50) or (50>10)
# Out:
# True

# %%
('vanilla' > 'chocolate') and (50 > 10)
# Out:
# True

# %%
#MEMBERSHIIP OPERATORS

# %%
ice_cream = 'i miss going to church'

'%%!miss' in ice_cream
# Out:
# False

# %%
celeb_day =[1, 3, 4, 5, 6, 11, 34]
wanted_day = 15

wanted_day in celeb_day
# Out:
# False

# %% [markdown]
# #if - elif - else statement

# %%
a = 33
b = 300

if  b>a:
    print('second is greater than first')
# Out:
# second is greater than first

# %%
#working with elif

# %%
if 25 < 10:
    print('it worked')
elif 25 < 30:
    print('1st elif worked')
elif 30 > 40:
    print('2nd elif worked')
else:
    print('it did not work....')
# Out:
# 1st elif worked

# %%
pass_mark = 70

if pass_mark >=90:
    print('Grade: A')
elif pass_mark >= 80:
     print('Grade: B')
elif pass_mark >= 70:
     print('Grade: C')
elif pass_mark >= 60:
     print('Grade: Qaite Okay')
else:
    print('Grade: Pass')
# Out:
# Grade: C

# %%
#adding logical operators

# %%
if (25 < 10) or (10>30):
    print('it worked')
elif 25 < 30:
    print('1st elif worked')
elif 30 > 40:
    print('2nd elif worked')
else:
    print('it did not work....')
# Out:
# 1st elif worked

# %%
age = 25

if age < 13:
    print('you are a child')
elif age < 20:
    print('you are teenager')
elif age < 65:
    print('you are an adult')
elif age >= 65:
    print('you are as senior')
else:
    print('enter your age please')
# Out:
# you are an adult

# %%
Month = 12

if Month == 1:
    print("January: world's new year celebration")
elif Month == 2:
    print("February: love month celebration")
elif Month == 3:
    print("March is Worlds Islamic fasting")
elif Month == 4:
    print("Worlds Islamic fasting ending")
elif Month == 5:
    print("Worlds labour celebration")
elif Month == 6:
    print("June: Mid year")
elif Month == 7:
    print("July: season of reoganizing")
elif Month == 8:
    print("August: Islamic Celebration")
elif Month == 9:
    print("September: Most Country election month")
elif Month == 10:
    print("October: Worlds breast cancer month")
elif Month == 11:
    print("Market price is watched")
elif Month == 12:
    print("December: World's Merry Christmas")
else:
    print('enter the month value')
# Out:
# December: World's Merry Christmas

# %%
#using logival operators in if statementa

# %%
a = 200
b = 40
c = 900

if (c > a) or (b>a):
    print('at least one of the condition is true')
# Out:
# at least one of the condition is true

# %%
a = 200
b = 40

if not (b>a):
    print('b is not greater than a')
# Out:
# b is not greater than a

# %%
age = 25
is_student = False
has_discout_code = True

if (age < 18 or age > 65) and not is_student or has_discout_code:
    print('dicount applies')
# Out:
# dicount applies

# %%
username = 'ooredoo'
password = 'secret1234'
is_verified = True

if username and password and not is_verified:
    print('successfully logged in')
else:
    print('login failed')
# Out:
# login failed

# %%
score = 80

if score >= 0 and score <= 100:
    print('valid score')
else:
    print('Invalid score')
# Out:
# valid score

# %%
#nested if statement

# %%
x = 13

if x > 10:
    print('above ten,')
    if x > 20:
        print('and also above 20!')
    else:
        print('but not above 20')
# Out:
# above ten,
# but not above 20

# %%
age = 25
has_licensed = True

if age >= 18:
    if has_licensed:
        print('above age limit and can drive')
    else:
        printprint('You cannot drive')
else:
    print('below age limit to drive')
# Out:
# above age limit and can drive

# %%
username = 'Amir'
password = 'Secret123'
is_active = True

if username:
    if password:
        if is_active:
            print('account is active')
        else:
            print('account is not active')
    else:
            print('password is Invalid')
else:
    rint('Username is required')
# Out:
# account is active

# %%
score = 76
extra_credit = 5

if score > 90:
    if extra_credit > 0:
        print('Grade: A+')
    else:
        print('Grade: A')
elif score > 80:
    print('Grade: B+')
else:
    print('Grade: C')
# Out:
# Grade: C

# %%
score = 80

if score > 90:
    Pass # this is excellent
    print('score is distinguahsed')

# %%
day = 4
match day:

    case 1 |2 |3 |4 |5:
        print('today is a weekday')
    case 6|7:
        print("it's the weekend")
# Out:
# today is a weekday
