# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\Worlds Telecom file.csv")

df
# Out:
#     Rank           Company Total revenue(US$ billion)        Country
# 0      1      China Mobile                  $140.5[1]          China
# 1      2           Verizon                    $134[2]  United States
# 2      3              AT&T                  $122.4[3]  United States
# 3      4           Comcast                  $121.6[4]  United States
# 4      5  Deutsche Telekom                  $120.7[5]        Germany
# ..   ...               ...                        ...            ...
# 84    85     Algar Telecom                   $1.1[85]         Brazil
# 85    86         Cable One                   $1.7[86]  United States
# 86    87          Mediacom                   $1.1[87]  United States
# 87    88            Vonage                   $1.0[88]  United States
# 88    89            Cell C                   $1.0[89]   South Africa
#
# [89 rows x 4 columns]

# %%
df.set_index('Rank')
# Out:
#                Company Total revenue(US$ billion)        Country
# Rank
# 1         China Mobile                  $140.5[1]          China
# 2              Verizon                    $134[2]  United States
# 3                 AT&T                  $122.4[3]  United States
# 4              Comcast                  $121.6[4]  United States
# 5     Deutsche Telekom                  $120.7[5]        Germany
# ...                ...                        ...            ...
# 85       Algar Telecom                   $1.1[85]         Brazil
# 86           Cable One                   $1.7[86]  United States
# 87            Mediacom                   $1.1[87]  United States
# 88              Vonage                   $1.0[88]  United States
# 89              Cell C                   $1.0[89]   South Africa
#
# [89 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        89 non-null     int64
#  1   Company                     89 non-null     object
#  2   Total revenue(US$ billion)  89 non-null     object
#  3   Country                     89 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.9+ KB

# %%
df.shape
# Out:
# (89, 4)

# %%
df.head(8)
# Out:
#    Rank                         Company Total revenue(US$ billion)  \
# 0     1                    China Mobile                  $140.5[1]
# 1     2                         Verizon                    $134[2]
# 2     3                            AT&T                  $122.4[3]
# 3     4                         Comcast                  $121.6[4]
# 4     5                Deutsche Telekom                  $120.7[5]
# 5     6  Nippon Telegraph and Telephone                   $97.4[6]
# 6     7                   China Telecom                   $70.3[7]
# 7     8                        SoftBank                   $55.2[8]
#
#          Country
# 0          China
# 1  United States
# 2  United States
# 3  United States
# 4        Germany
# 5          Japan
# 6          China
# 7          Japan

# %%
df.tail(8)
# Out:
#     Rank                      Company Total revenue(US$ billion)  \
# 81    82                          Eir                   $1.3[82]
# 82    83                  Vocus Group                   $1.3[83]
# 83    84  Consolidated Communications                   $1.2[84]
# 84    85                Algar Telecom                   $1.1[85]
# 85    86                    Cable One                   $1.7[86]
# 86    87                     Mediacom                   $1.1[87]
# 87    88                       Vonage                   $1.0[88]
# 88    89                       Cell C                   $1.0[89]
#
#           Country
# 81        Ireland
# 82      Australia
# 83  United States
# 84         Brazil
# 85  United States
# 86  United States
# 87  United States
# 88   South Africa

# %%
df.loc[83]
# Out:
# Rank                                                   84
# Company                       Consolidated Communications
# Total revenue(US$ billion)                       $1.2[84]
# Country                                     United States
# Name: 83, dtype: object

# %%
df.iloc[12]
# Out:
# Rank                                     13
# Company                       América Móvil
# Total revenue(US$ billion)        $43.6[13]
# Country                              Mexico
# Name: 12, dtype: object

# %%
df.loc[df['Country'] == 'Ireland']
# Out:
#     Rank Company Total revenue(US$ billion)  Country
# 81    82     Eir                   $1.3[82]  Ireland

# %%
df.iloc[:, [0,2]]
# Out:
#     Rank Total revenue(US$ billion)
# 0      1                  $140.5[1]
# 1      2                    $134[2]
# 2      3                  $122.4[3]
# 3      4                  $121.6[4]
# 4      5                  $120.7[5]
# ..   ...                        ...
# 84    85                   $1.1[85]
# 85    86                   $1.7[86]
# 86    87                   $1.1[87]
# 87    88                   $1.0[88]
# 88    89                   $1.0[89]
#
# [89 rows x 2 columns]

# %%
df.loc[df['Country'] != 'United States']
# Out:
#     Rank                         Company Total revenue(US$ billion)  \
# 0      1                    China Mobile                  $140.5[1]
# 4      5                Deutsche Telekom                  $120.7[5]
# 5      6  Nippon Telegraph and Telephone                   $97.4[6]
# 6      7                   China Telecom                   $70.3[7]
# 7      8                        SoftBank                   $55.2[8]
# ..   ...                             ...                        ...
# 77    78             Digi Communications                   $1.7[78]
# 81    82                             Eir                   $1.3[82]
# 82    83                     Vocus Group                   $1.3[83]
# 84    85                   Algar Telecom                   $1.1[85]
# 88    89                          Cell C                   $1.0[89]
#
#          Country
# 0          China
# 4        Germany
# 5          Japan
# 6          China
# 7          Japan
# ..           ...
# 77       Romania
# ...

# %%
df.loc[:, 'Rank':'Country']
# Out:
#     Rank           Company Total revenue(US$ billion)        Country
# 0      1      China Mobile                  $140.5[1]          China
# 1      2           Verizon                    $134[2]  United States
# 2      3              AT&T                  $122.4[3]  United States
# 3      4           Comcast                  $121.6[4]  United States
# 4      5  Deutsche Telekom                  $120.7[5]        Germany
# ..   ...               ...                        ...            ...
# 84    85     Algar Telecom                   $1.1[85]         Brazil
# 85    86         Cable One                   $1.7[86]  United States
# 86    87          Mediacom                   $1.1[87]  United States
# 87    88            Vonage                   $1.0[88]  United States
# 88    89            Cell C                   $1.0[89]   South Africa
#
# [89 rows x 4 columns]

# %%
df.iloc[1]
# Out:
# Rank                                      2
# Company                             Verizon
# Total revenue(US$ billion)          $134[2]
# Country                       United States
# Name: 1, dtype: object
