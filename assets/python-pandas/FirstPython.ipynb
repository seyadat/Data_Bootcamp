# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # VARIABLES IN PYTHON

# %%
X = 22

print(X)
# Out:
# 22

# %%
#checking the datatype and are case-sensitive

# %%
type(X)
# Out:
# int

# %%
y = 'Mini Coco Chocolate'
print(y)
# Out:
# Mini Coco Chocolate

# %%
#checking the datatype

# %%
type (y)
# Out:
# str

# %%
#assign multiple value to multi variables

# %%
x, y, z = 'Chocolate', 'Vanilla', 'India Cream'

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# India Cream

# %%
x= y= z = 'Chocolate Vanilla made from India Cream'

print(x)
print(y)
print(z)
# Out:
# Chocolate Vanilla made from India Cream
# Chocolate Vanilla made from India Cream
# Chocolate Vanilla made from India Cream

# %% [markdown]
# # LIST

# %%
#working with variables in list

# %%
ice_cream =['Chocolate', 'Vanilla', 'Black Conni']

x, y, z = ice_cream

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Black Conni

# %%
#in variables (str goes with str) & (int goes with int)

# %%
x = 'favorite ice cream flavour is' + 'Choco Milo'

print(x)
# Out:
# favorite ice cream flavour isChoco Milo

# %%
y = 4 * 6

print(y)
# Out:
# 24

# %%
x = 'ice cream'
y = ' tastes'
z = ' much better'

print(x+y+z)
# Out:
# ice cream tastes much better

# %%
#variables(strings works with int by comma's(,))

# %%
x = 'Choco flavor at vendor at'
y = 2

print(x, y)
# Out:
# Choco flavor at vendor at 2
