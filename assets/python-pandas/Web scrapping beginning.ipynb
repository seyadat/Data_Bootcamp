# %% [markdown]
# # WEB SCRAPPING

# %%
#BEAUTIFULSOUP AND REQUEST

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = https://www.statsghana.gov.gh/gssdatadownloadspage.php

page = requests.get(url)
# Out:
#   Cell In[5], line 1
#     url = https://www.statsghana.gov.gh/gssdatadownloadspage.php
#                ^
# SyntaxError: invalid syntax

# %%
soup = beautifulSoup(page.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 soup = beautifulSoup(page.text, 'html.parser')
#
# NameError: name 'beautifulSoup' is not defined

# %% [markdown]
# # find & find_all

# %%
from bs4 import BeautifulSoup
import requests

# %% [raw]
# url = https://www.statsghana.gov.gh/gssdatadownloadspage.php

# %%
Page = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Page = requests.get(url)
#
# NameError: name 'url' is not defined

# %%
SoBeautifulSoup(page.text,'html.parser' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 BeautifulSoup(page.text,'html.parser' )
#
# NameError: name 'page' is not defined

# %%
#USING DATA FROMabs

2025 FIVB Volleyball Men’s World Championship

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.volleyballworld.com/volleyball/competitions/men-world-championship/statistics/best-scorers/'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
# FING AND FIND_ALL

#DATA SOURCE ->  2025 FIVB Volleyball Men’s World Championship

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.volleyballworld.com/volleyball/competitions/men-world-championship/statistics/best-scorers/'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
soup.find('div', class_='d3-1-col__col-12')

# %%
soup.find_all('th')
# Out:
# [<th class="vbw-o-table__header rank" scope="col"><span class="full-text">Rank</span><span class="abbreviated-text">Rank</span></th>,
#  <th class="vbw-o-table__header playername" scope="col"><span class="full-text">Player Name</span><span class="abbreviated-text">Player</span></th>,
#  <th class="vbw-o-table__header federation" scope="col"><span class="full-text">Team</span><span class="abbreviated-text">Team</span></th>,
#  <th class="vbw-o-table__header points" scope="col"><span class="full-text">Points</span><span class="abbreviated-text">Pts</span></th>,
#  <th class="vbw-o-table__header attacks" scope="col"><span class="full-text">Attack Points</span><span class="abbreviated-text">A Pts</span></th>,
#  <th class="vbw-o-table__header blocks" scope="col"><span class="full-text">Block Points</span><span class="abbreviated-text">B Pts</span></th>,
# ...

# %%
soup.find('th').text.strip()
# Out:
# 'RankRank'
