# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import selenium as sel

# %%
df = pd.read_csv(r"C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python\bike_sales.csv")
df
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   11/26/2013   26   November  2013            19           Youth (<25)
# 1   11/26/2015   26   November  2015            19           Youth (<25)
# 2    3/23/2014   23      March  2014            49        Adults (35-64)
# 3    3/23/2016   23      March  2016            49        Adults (35-64)
# 4    5/15/2014   15        May  2014            47        Adults (35-64)
# ..         ...  ...        ...   ...           ...                   ...
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 96   9/20/2013   20  September  2013            32  Young Adults (25-34)
# 97   9/20/2015   20  September  2015            32  Young Adults (25-34)
# 98  10/25/2013   25    October  2013            32  Young Adults (25-34)
# 99  10/25/2015   25    October  2015            32  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              100 non-null    object
#  1   Day               100 non-null    int64
#  2   Month             100 non-null    object
#  3   Year              100 non-null    int64
#  4   Customer_Age      100 non-null    int64
#  5   Age_Group         100 non-null    object
#  6   Customer_Gender   100 non-null    object
#  7   Country           100 non-null    object
#  8   State             100 non-null    object
#  9   Product_Category  100 non-null    object
#  10  Sub_Category      100 non-null    object
#  11  Product           100 non-null    object
#  12  Order_Quantity    100 non-null    int64
#  13  Unit_Cost         100 non-null    int64
#  14  Unit_Price        100 non-null    int64
#  15  Profit            100 non-null    int64
# ...

# %%
#converting all the price col from int to float
#Unit_Cost, Unit price, Profit,	Cost,	Revenue

df[['Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']] = df[['Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']].astype(float)
df
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   11/26/2013   26   November  2013            19           Youth (<25)
# 1   11/26/2015   26   November  2015            19           Youth (<25)
# 2    3/23/2014   23      March  2014            49        Adults (35-64)
# 3    3/23/2016   23      March  2016            49        Adults (35-64)
# 4    5/15/2014   15        May  2014            47        Adults (35-64)
# ..         ...  ...        ...   ...           ...                   ...
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 96   9/20/2013   20  September  2013            32  Young Adults (25-34)
# 97   9/20/2015   20  September  2015            32  Young Adults (25-34)
# 98  10/25/2013   25    October  2013            32  Young Adults (25-34)
# 99  10/25/2015   25    October  2015            32  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# ...

# %%
#print(df.dtypes)

df.describe()
# Out:
#               Day         Year  Customer_Age  Order_Quantity  Unit_Cost  \
# count  100.000000   100.000000    100.000000      100.000000      100.0
# mean    17.660000  2014.440000     39.320000        9.360000       45.0
# std      8.863978     1.122047      9.962434        7.641619        0.0
# min      2.000000  2013.000000     19.000000        1.000000       45.0
# 25%     12.000000  2013.000000     32.000000        4.000000       45.0
# 50%     18.000000  2014.500000     38.000000        7.000000       45.0
# 75%     25.000000  2015.000000     47.000000       11.250000       45.0
# max     31.000000  2016.000000     61.000000       30.000000       45.0
#
#        Unit_Price       Profit         Cost      Revenue
# count       100.0   100.000000   100.000000   100.000000
# mean        120.0   624.150000   421.200000  1045.350000
# std           0.0   526.788045   343.872862   867.137511
# min         120.0    49.000000    45.000000    94.000000
# ...

# %%
#checking for missing values

df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
#checking for unique values

df.nunique()
# Out:
# Date                94
# Day                 22
# Month               11
# Year                 4
# Customer_Age        20
# Age_Group            3
# Customer_Gender      2
# Country              6
# State               13
# Product_Category     1
# Sub_Category         1
# Product              1
# Order_Quantity      27
# Unit_Cost            1
# Unit_Price           1
# Profit              61
# Cost                27
# Revenue             60
# dtype: int64

# %%
df.sort_values(by='Revenue', ascending=False).head(5)
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 90   2/12/2014   12   February  2014            46        Adults (35-64)
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 91   2/12/2016   12   February  2016            46        Adults (35-64)
# 94   9/23/2013   23  September  2013            41        Adults (35-64)
# 36  11/11/2013   11   November  2013            34  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# 90               M  United States        California      Accessories
# 95               F        Germany            Hessen      Accessories
# 91               M  United States        California      Accessories
# 94               F        Germany            Hessen      Accessories
# 36               M         Canada  British Columbia      Accessories
#
#    Sub_Category              Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %%
#Correlations =>df.corr() 
    #=>correlation compares column by every column and check how close correlated they are to each values are close to each other and outline them 

df.corr()
#faced with error coz the df data is a string col

# %%
sns.heatmap(df.corr(), annot= True)
plt.rcarams['figure.figsize'] = (19, 8)
plt.show()

#ERROR exe coz i decided not to convert the str date col
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 sns.heatmap(df.corr(), annot= True)
#       2 plt.rcarams['figure.figsize'] = (19, 8)
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
df
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   11/26/2013   26   November  2013            19           Youth (<25)
# 1   11/26/2015   26   November  2015            19           Youth (<25)
# 2    3/23/2014   23      March  2014            49        Adults (35-64)
# 3    3/23/2016   23      March  2016            49        Adults (35-64)
# 4    5/15/2014   15        May  2014            47        Adults (35-64)
# ..         ...  ...        ...   ...           ...                   ...
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 96   9/20/2013   20  September  2013            32  Young Adults (25-34)
# 97   9/20/2015   20  September  2015            32  Young Adults (25-34)
# 98  10/25/2013   25    October  2013            32  Young Adults (25-34)
# 99  10/25/2015   25    October  2015            32  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# ...

# %%
#df.groupby('Country').mean()
#Error coz the dtype agg issue so to exec only numeric col only

df_numeric = df.select_dtypes(include=["number"])
df.groupby("Country")[df_numeric.columns].mean()
# Out:
#                       Day         Year  Customer_Age  Order_Quantity  \
# Country
# Australia       19.500000  2014.625000     40.250000        9.937500
# Canada          16.312500  2014.375000     37.000000        8.593750
# France          18.666667  2014.000000     42.333333       13.333333
# Germany         18.333333  2014.000000     32.666667       12.500000
# United Kingdom  17.000000  2014.000000     29.000000       15.000000
# United States   17.789474  2014.578947     42.000000        8.342105
#
#                 Unit_Cost  Unit_Price       Profit        Cost      Revenue
# Country
# Australia            45.0       120.0   536.687500  447.187500   983.875000
# Canada               45.0       120.0   634.250000  386.718750  1020.968750
# France               45.0       120.0   786.833333  600.000000  1386.833333
# Germany              45.0       120.0   792.666667  562.500000  1355.166667
# United Kingdom       45.0       120.0  1053.000000  675.000000  1728.000000
# ...

# %%
#sorting Revenue out in a descending

df1= df.groupby("Country")[df_numeric.columns].mean().sort_values(by='Revenue', ascending=False)
df1
# Out:
#                       Day         Year  Customer_Age  Order_Quantity  \
# Country
# United Kingdom  17.000000  2014.000000     29.000000       15.000000
# France          18.666667  2014.000000     42.333333       13.333333
# Germany         18.333333  2014.000000     32.666667       12.500000
# Canada          16.312500  2014.375000     37.000000        8.593750
# Australia       19.500000  2014.625000     40.250000        9.937500
# United States   17.789474  2014.578947     42.000000        8.342105
#
#                 Unit_Cost  Unit_Price       Profit        Cost      Revenue
# Country
# United Kingdom       45.0       120.0  1053.000000  675.000000  1728.000000
# France               45.0       120.0   786.833333  600.000000  1386.833333
# Germany              45.0       120.0   792.666667  562.500000  1355.166667
# Canada               45.0       120.0   634.250000  386.718750  1020.968750
# Australia            45.0       120.0   536.687500  447.187500   983.875000
# ...

# %%
#want to visual x or yabs

df2 = df1.transpose()
df2
# Out:
# Country         United Kingdom       France      Germany      Canada  \
# Day                       17.0    18.666667    18.333333    16.31250
# Year                    2014.0  2014.000000  2014.000000  2014.37500
# Customer_Age              29.0    42.333333    32.666667    37.00000
# Order_Quantity            15.0    13.333333    12.500000     8.59375
# Unit_Cost                 45.0    45.000000    45.000000    45.00000
# Unit_Price               120.0   120.000000   120.000000   120.00000
# Profit                  1053.0   786.833333   792.666667   634.25000
# Cost                     675.0   600.000000   562.500000   386.71875
# Revenue                 1728.0  1386.833333  1355.166667  1020.96875
#
# Country         Australia  United States
# Day               19.5000      17.789474
# Year            2014.6250    2014.578947
# Customer_Age      40.2500      42.000000
# Order_Quantity     9.9375       8.342105
# Unit_Cost         45.0000      45.000000
# ...

# %%
#visualizing

df2.plot()
# Out:
# <Axes: >

# %%
df2.boxplot(figsize=(10, 5))
# Out:
# <Axes: >

# %%
df
# Out:
#           Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0   11/26/2013   26   November  2013            19           Youth (<25)
# 1   11/26/2015   26   November  2015            19           Youth (<25)
# 2    3/23/2014   23      March  2014            49        Adults (35-64)
# 3    3/23/2016   23      March  2016            49        Adults (35-64)
# 4    5/15/2014   15        May  2014            47        Adults (35-64)
# ..         ...  ...        ...   ...           ...                   ...
# 95   9/23/2015   23  September  2015            41        Adults (35-64)
# 96   9/20/2013   20  September  2013            32  Young Adults (25-34)
# 97   9/20/2015   20  September  2015            32  Young Adults (25-34)
# 98  10/25/2013   25    October  2013            32  Young Adults (25-34)
# 99  10/25/2015   25    October  2015            32  Young Adults (25-34)
#
#    Customer_Gender        Country             State Product_Category  \
# ...

# %%
df.select_dtypes(include='float')
# Out:
#     Unit_Cost  Unit_Price  Profit    Cost  Revenue
# 0        45.0       120.0   590.0   360.0    950.0
# 1        45.0       120.0   590.0   360.0    950.0
# 2        45.0       120.0  1366.0  1035.0   2401.0
# 3        45.0       120.0  1188.0   900.0   2088.0
# 4        45.0       120.0   238.0   180.0    418.0
# ..        ...         ...     ...     ...      ...
# 95       45.0       120.0  1931.0  1305.0   3236.0
# 96       45.0       120.0   146.0   135.0    281.0
# 97       45.0       120.0    49.0    45.0     94.0
# 98       45.0       120.0   581.0   360.0    941.0
# 99       45.0       120.0   653.0   405.0   1058.0
#
# [100 rows x 5 columns]
