# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Seyy_\Downloads\Electric_Vehicle_Population_Data.csv")

# %%
df
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# 1       WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# 2       5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# 3       5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# 4       5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...            ...        ...         ...   ...          ...         ...
# 269668  5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# 269669  5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# 269670  5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# 269671  7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# 269672  JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Make    Model                   Electric Vehicle Type  \
# ...

# %%
df[df['Model Year'] >= 2018]
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 1       WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# 2       5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# 3       5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# 4       5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# 5       1G1FZ6S00L   Thurston     Olympia    WA      98506.0        2020
# ...            ...        ...         ...   ...          ...         ...
# 269667  WVGJNPE25N      Lewis    Packwood    WA      98377.0        2022
# 269669  5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# 269670  5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# 269671  7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# 269672  JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#               Make    Model                   Electric Vehicle Type  \
# ...

# %%
#using IsIn syntax

# %%
specific_city = ['Bow', 'Packwood']

df[df['City'].isin(specific_city)]
# Out:
#         VIN (1-10)  County      City State  Postal Code  Model Year  \
# 258     1G1FZ6S08K  Skagit       Bow    WA      98232.0        2019
# 98665   7SAYGDEDXT  Skagit       Bow    WA      98232.0        2026
# 103057  5YJ3E1EA0L  Skagit       Bow    WA      98232.0        2020
# 112679  7SAYGDEE3P  Skagit       Bow    WA      98232.0        2023
# 116873  3C3CFFGE0H  Skagit       Bow    WA      98232.0        2017
# ...            ...     ...       ...   ...          ...         ...
# 267142  5YJ3E1EA5L  Skagit       Bow    WA      98232.0        2020
# 267848  WA1LAAGE5M  Skagit       Bow    WA      98232.0        2021
# 268673  JTMAB3FV7P   Lewis  Packwood    WA      98361.0        2023
# 269667  WVGJNPE25N   Lewis  Packwood    WA      98377.0        2022
# 269670  5YJYGDEF5M  Skagit       Bow    WA      98232.0        2021
#
#               Make              Model                   Electric Vehicle Type  \
# ...

# %%
#Contains sSyntaxError

# %%
df[df['City'].str.contains('Lynnwood', na=False)]
# Out:
#         VIN (1-10)     County      City State  Postal Code  Model Year  \
# 96      WBY43HD03S  Snohomish  Lynnwood    WA      98037.0        2025
# 199     KNDCR3L1XP  Snohomish  Lynnwood    WA      98087.0        2023
# 205     5YJ3E1EAXK  Snohomish  Lynnwood    WA      98087.0        2019
# 218     1N4BZ1CP7K  Snohomish  Lynnwood    WA      98037.0        2019
# 227     5YJSA1H14E  Snohomish  Lynnwood    WA      98087.0        2014
# ...            ...        ...       ...   ...          ...         ...
# 269578  5YJYGDEEXM  Snohomish  Lynnwood    WA      98037.0        2021
# 269642  WP1AD2XAXS  Snohomish  Lynnwood    WA      98037.0        2025
# 269647  7SAYGDEE2P  Snohomish  Lynnwood    WA      98036.0        2023
# 269653  1GYKPNRL0S  Snohomish  Lynnwood    WA      98037.0        2025
# 269671  7SAYGDEE0S  Snohomish  Lynnwood    WA      98087.0        2025
#
#             Make    Model           Electric Vehicle Type  \
# ...

# %%
# Filter rows where 'City' is 'New York'abs

new_gene = df[(df['Make'] == 'NISSAN') & (df['Electric Range'] >= 150)]
print (new_gene)
# Out:
#         VIN (1-10)        County          City State  Postal Code  Model Year  \
# 47      1N4AZ1CP6K     Snohomish    Mill Creek    WA      98012.0        2019
# 84      1N4AZ1CP5K        Kitsap     Indianola    WA      98342.0        2019
# 109     1N4BZ1DP8L        Kitsap      Kingston    WA      98346.0        2020
# 126     1N4AZ1CP0J        Kitsap       Poulsbo    WA      98370.0        2018
# 141     1N4AZ1CP8K        Kitsap      Kingston    WA      98346.0        2019
# ...            ...           ...           ...   ...          ...         ...
# 268872  1N4BZ1CP0L  Grays Harbor      Aberdeen    WA      98520.0        2020
# 268888  1N4BZ1CP3K     Snohomish      Lynnwood    WA      98037.0        2019
# 269237  1N4AZ1CPXK       Clallam  Port Angeles    WA      98363.0        2019
# 269517  1N4BZ1CP9K     Snohomish       Edmonds    WA      98026.0        2019
# 269596  1N4AZ1CP9J          King   Woodinville    WA      98072.0        2018
#
# ...

# %%
df
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# 1       WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# 2       5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# 3       5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# 4       5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...            ...        ...         ...   ...          ...         ...
# 269668  5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# 269669  5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# 269670  5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# 269671  7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# 269672  JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Make    Model                   Electric Vehicle Type  \
# ...

# %%
d2 = df.set_index('Make')
d2
# Out:
#          VIN (1-10)     County        City State  Postal Code  Model Year  \
# Make
# FIAT     3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# PORSCHE  WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# TESLA    5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# TESLA    5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# TESLA    5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...             ...        ...         ...   ...          ...         ...
# TESLA    5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# TESLA    5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# TESLA    5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# TESLA    7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# MAZDA    JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Model                   Electric Vehicle Type  \
# Make
# ...

# %%
#using filter functionabs

d2.filter(items=['Model Year', 'Electric Range'], axis= 1)
# Out:
#          Model Year  Electric Range
# Make
# FIAT           2016            84.0
# PORSCHE        2020           203.0
# TESLA          2018           215.0
# TESLA          2020           291.0
# TESLA          2018           238.0
# ...             ...             ...
# TESLA          2015           208.0
# TESLA          2024             0.0
# TESLA          2021             0.0
# TESLA          2025             0.0
# MAZDA          2025            26.0
#
# [269673 rows x 2 columns]

# %%
d2.filter(like= 'Mazda', axis= 0)
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %%
#order by

# %%
df
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# 1       WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# 2       5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# 3       5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# 4       5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...            ...        ...         ...   ...          ...         ...
# 269668  5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# 269669  5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# 269670  5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# 269671  7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# 269672  JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Make    Model                   Electric Vehicle Type  \
# ...

# %%
#sorting by a single column

df[df['Model Year'] == 2025].sort_values(by='Electric Range', ascending=False )
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 35441   SAL1L9E47S       King      Newcastle    WA      98059.0        2025
# 38948   SAL1L9E45S       King        Seattle    WA      98112.0        2025
# 180043  SAL1L9E44S  Snohomish        Everett    WA      98203.0        2025
# 115617  SAL1L9E45S       King      Newcastle    WA      98059.0        2025
# 65330   SAL1L9E46S       King        Seattle    WA      98102.0        2025
# ...            ...        ...            ...   ...          ...         ...
# 269419  7SAYGDEE4S       King        Redmond    WA      98052.0        2025
# 34609   ZHWUC1ZM5S       King        Seattle    WA      98125.0        2025
# 52720   ZHWUC1ZM3S       King  Mercer Island    WA      98040.0        2025
# 181964  ZHWUC1ZM5S  Snohomish      Snohomish    WA      98296.0        2025
# 254561  ZHWUC1ZM9S    Spokane        Spokane    WA      99005.0        2025
#
#                Make              Model  \
# ...

# %%
#sorting by a multiple columns

df[df['Model Year'] == 2025].sort_values(by=['Legislative District','Electric Range'], ascending=False )
# Out:
#         VIN (1-10)           County           City State  Postal Code  \
# 42895   W1NKM5GB2S            Clark      Vancouver    WA      98661.0
# 50868   W1NKM5GB8S            Clark      Vancouver    WA      98665.0
# 77935   W1NKM5GB8S            Clark      Vancouver    WA      98662.0
# 91670   W1NKM5GB7S            Clark      Vancouver    WA      98665.0
# 110749  W1NKM5GB4S            Clark      Vancouver    WA      98664.0
# ...            ...              ...            ...   ...          ...
# 265095  3GN7DNRR4S          Hampden  Feeding Hills    MA       1030.0
# 266623  5YJ3E1EA4S       Alexandria     Alexandria    VA      22311.0
# 266970  KM8KNDA8XS  San Luis Obispo  Arroyo Grande    CA      93420.0
# 268588  3GNKDGRJ2S       Montgomery   Gaithersburg    MD      20878.0
# 269092  3GNKDERL4S     Anne Arundel       Pasadena    MD      21122.0
#
#         Model Year           Make      Model  \
# 42895         2025  MERCEDES-BENZ  GLC-CLASS
# ...
