# %%
#Indexing
#=>kinda a label

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Seyy_\Downloads\Electric_Vehicle_Population_Data.csv", index_col='Make')
df
# Out:
#          VIN (1-10)     County        City State  Postal Code  Model Year  \
# Make
# FIAT     3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# PORSCHE  WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# TESLA    5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# TESLA    5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# TESLA    5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...             ...        ...         ...   ...          ...         ...
# TESLA    5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# TESLA    5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# TESLA    5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# TESLA    7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# MAZDA    JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Model                   Electric Vehicle Type  \
# Make
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Make', inplace=True)

df
# Out:
#          VIN (1-10)     County        City State  Postal Code  Model Year  \
# Make
# FIAT     3C3CFFGE1G     Yakima      Yakima    WA      98908.0        2016
# PORSCHE  WP0AB2Y16L       King      Auburn    WA      98092.0        2020
# TESLA    5YJ3E1EB2J       King     Seattle    WA      98109.0        2018
# TESLA    5YJYGDEF5L       King     Seattle    WA      98125.0        2020
# TESLA    5YJXCBE22J   Thurston     Olympia    WA      98501.0        2018
# ...             ...        ...         ...   ...          ...         ...
# TESLA    5YJSA1E24F   Thurston       Lacey    WA      98516.0        2015
# TESLA    5YJ3E1EB7R   Kittitas  Ellensburg    WA      98926.0        2024
# TESLA    5YJYGDEF5M     Skagit         Bow    WA      98232.0        2021
# TESLA    7SAYGDEE0S  Snohomish    Lynnwood    WA      98087.0        2025
# MAZDA    JM3KKEHA0S   Thurston     Olympia    WA      98516.0        2025
#
#            Model                   Electric Vehicle Type  \
# Make
# ...

# %%
df.loc['TESLA']
# Out:
#        VIN (1-10)     County               City State  Postal Code  \
# Make
# TESLA  5YJ3E1EB2J       King            Seattle    WA      98109.0
# TESLA  5YJYGDEF5L       King            Seattle    WA      98125.0
# TESLA  5YJXCBE22J   Thurston            Olympia    WA      98501.0
# TESLA  5YJ3E1EA0N     Yakima              Moxee    WA      98936.0
# TESLA  5YJSA1E29J     Kitsap  Bainbridge Island    WA      98110.0
# ...           ...        ...                ...   ...          ...
# TESLA  7SAYGDEE8T       King            Redmond    WA      98052.0
# TESLA  5YJSA1E24F   Thurston              Lacey    WA      98516.0
# TESLA  5YJ3E1EB7R   Kittitas         Ellensburg    WA      98926.0
# TESLA  5YJYGDEF5M     Skagit                Bow    WA      98232.0
# TESLA  7SAYGDEE0S  Snohomish           Lynnwood    WA      98087.0
#
#        Model Year    Model           Electric Vehicle Type  \
# Make
# TESLA        2018  MODEL 3  Battery Electric Vehicle (BEV)
# ...

# %%
#MULTIPLY INDEXING

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['Electric Vehicle Type', 'Make'], inplace=True)

# %%
df.sort_index()
# Out:
#                                                              VIN (1-10)  \
# Electric Vehicle Type                  Make
# Battery Electric Vehicle (BEV)         ACURA                 4W5KHNRL4R
#                                        ACURA                 4W5KHNRL9R
#                                        ACURA                 4W5XHPRL2R
#                                        ACURA                 4W5KHNRL9R
#                                        ACURA                 4W5KHNRL9R
# ...                                                                 ...
# Plug-in Hybrid Electric Vehicle (PHEV) VOLVO                 YV4H60DLXN
#                                        VOLVO                 YV4H60RC1S
#                                        VOLVO                 YV4H60RM3T
#                                        WHEEGO ELECTRIC CARS  1W9WL21B6A
#                                        WHEEGO ELECTRIC CARS  1W9WL21BXA
#
# ...
