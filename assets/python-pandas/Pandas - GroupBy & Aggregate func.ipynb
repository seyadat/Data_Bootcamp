# %%
import pandas as pd 
import os

# %%
os.chdir(r'C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python')
print(os.getcwd())
# Out:
# C:\Users\Seyy_\OneDrive\Desktop\jupyter projects\alex the analyst bootcamp\python

# %%
df = pd.read_excel(r"C:\Users\Seyy_\OneDrive\Desktop\sql data analyst practice file\excel practice\WorkTheData-bikestores\BikeStores.xlsx", index_col='order_id')
df
# Out:
#                     customers        city state order_date  total_units  \
# order_id
# 1         Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# 1         Johnathan Velazquez  Pleasanton    CA 2016-01-01            1
# 1         Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# 1         Johnathan Velazquez  Pleasanton    CA 2016-01-01            1
# 1         Johnathan Velazquez  Pleasanton    CA 2016-01-01            2
# ...                       ...         ...   ...        ...          ...
# 1614          Dorthey Jackson     Houston    TX 2018-11-28            1
# 1614          Dorthey Jackson     Houston    TX 2018-11-28            2
# 1615             Sarita Parks      Forney    TX 2018-12-28            1
# 1615             Sarita Parks      Forney    TX 2018-12-28            1
# 1615             Sarita Parks      Forney    TX 2018-12-28            2
#
#           revenue                                    product_name  \
# order_id
# ...

# %%
#Group By eg df.groupby()

# %%
st_group = df.groupby('store_name')

# %%
st_group.mean(numeric_only=True)
# Out:
#                   total_units
# store_name
# Baldwin Bikes        1.495775
# Rowlett Bikes        1.502879
# Santa Cruz Bikes     1.506958

# %%
#checking the dataypesabs
df.select_dtypes(include='number').columns

#st_group[['total_units', 'revenue']].mean()
# Out:
# Index(['total_units'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4722 entries, 1 to 1615
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customers      4722 non-null   object
#  1   city           4722 non-null   object
#  2   state          4722 non-null   object
#  3   order_date     4722 non-null   datetime64[ns]
#  4   total_units    4722 non-null   int64
#  5   revenue        4722 non-null   object
#  6   product_name   4722 non-null   object
#  7   category_name  4722 non-null   object
#  8   brand_name     4722 non-null   object
#  9   store_name     4722 non-null   object
#  10  sales_rep      4722 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 442.7+ KB

# %%
#imported a new csv file to work

# %%
df1 = pd.read_csv(r"C:\Users\Seyy_\Downloads\csv folder\datasets.csv",index_col= 'id')

df1

# %%
room_group = df1.groupby('room_type')

# %%
room_group.mean(numeric_only=True)
# Out:
#                       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  1.640295e+08  40.726309 -73.947094  222.966381
# Hotel room       2.332673e+08  40.745921 -73.984082  415.053571
# Private room     1.873515e+08  40.727373 -73.928882  139.572566
# Shared room      2.087156e+08  40.723141 -73.919229  156.680412
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt       29.423713          39.485764           1.172741
# Hotel room             8.776786          57.696429           1.221964
# Private room          27.736226          46.295127           1.366075
# Shared room           26.703072          49.378840           1.357952
#
#                  calculated_host_listings_count  availability_365  \
# room_type
# Entire home/apt                       20.457118        208.761315
# Hotel room                            30.312500        273.178571
# ...

# %%
room_group.count()
# Out:
#                   name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt  11555    11555      11555                11555
# Hotel room         112      112        112                  112
# Private room      8803     8803       8803                 8803
# Shared room        293      293        293                  293
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt          11555     11555      11555  11541           11555
# Hotel room                 112       112        112    112             112
# Private room              8803      8803       8803   8792            8803
# Shared room                293       293        293    291             293
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt              11555        11555              11555
# Hotel room                     112          112                112
# ...

# %%
room_group.min()
# Out:
#                                                               name  host_id  \
# room_type
# Entire home/apt   Aparthotel in New York · Studio · 1 bed · 1 bath     2234
# Hotel room       Bed and breakfast in New York · Studio · 1 bed...   417504
# Private room     Aparthotel in New York · ★4.49 · 1 bedroom · 2...     1678
# Shared room      Bungalow in Brooklyn · ★4.60 · 2 bedrooms · 2 ...     8703
#
#                   host_name neighbourhood_group neighbourhood   latitude  \
# room_type
# Entire home/apt      #NAME?               Bronx      Allerton  40.500314
# Hotel room       Arlo NoMad            Brooklyn       Chelsea  40.718699
# Private room            475               Bronx      Allerton  40.541530
# Shared room               A               Bronx       Arverne  40.546247
#
#                  longitude  price  minimum_nights  number_of_reviews  \
# room_type
# Entire home/apt -74.249840   10.0             1.0                1.0
# ...

# %%
room_group.max()
# Out:
#                                                               name    host_id  \
# room_type
# Entire home/apt  casa particular in The Bronx · ★4.52 · 1 bedro...  550403525
# Hotel room       Serviced apartment in New York · ★4.79 · 4 bed...  496932087
# Private room     casa particular in The Bronx · ★4.09 · 1 bedro...  549467833
# Shared room      casa particular in Queens · ★5.0 · 1 bedroom ·...  526029430
#
#                                       host_name neighbourhood_group  \
# room_type
# Entire home/apt                           Ирина       Staten Island
# Hotel room       Walker Hotel Greenwich Village              Queens
# Private room                                 玉姗       Staten Island
# Shared room                             Zachary       Staten Island
#
#                 neighbourhood   latitude  longitude     price  minimum_nights  \
# room_type
# Entire home/apt      Woodside  40.911147 -73.713836   10000.0          1250.0
# ...

# %%
room_group.sum()
# Out:
#                                                               name  \
# room_type
# Entire home/apt  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# Hotel room       Serviced apartment in New York City · Studio ·...
# Private room     Rental unit in Brooklyn · ★5.0 · 1 bedroomRent...
# Shared room      Rental unit in Brooklyn · 1 bedroom · 1 bed · ...
#
#                        host_id  \
# room_type
# Entire home/apt  1895360877298
# Hotel room         26125939156
# Private room     1649255270290
# Shared room        61153665316
#
#                                                          host_name  \
# room_type
# Entire home/apt  JenifferJoshuaStay With VibeJenifferJenifferJo...
# Hotel room       Chamber HotelVidaArlo SoHoChamber HotelIncentr...
# Private room     WalterJohn And CatherineJohn And CatherineMarg...
# Shared room      AlexJohn J.John J.Shane & ShreshthAnastasiaJo'...
#
#                                                neighbourhood_group  \
# room_type
# ...

# %%
#aggregating a specific column like price

# %%
df1.groupby('room_type').agg({'price':['mean', 'min', 'sum', 'max', 'count'], 'neighbourhood_group':['count','nunique', 'first']})

# %%
df1.groupby('room_type').describe()
