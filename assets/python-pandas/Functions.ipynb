# %%
#FUNCTIONS()
    #BLOCK OF CODE THAT RUN WHEN CALLED

# %%
def fist_name():
    print('the name is Faisal')

# %%
 fist_name()
# Out:
# the name is Faisal

# %%
#argument functions.

# %%
def numb_square(number):
    print(number**5)

# %%
numb_square(5)
# Out:
# 3125

# %%
#multivalues

# %%
def multi_square(number,sqrt):
    print(number**sqrt)

# %%
multi_square(10,4)
multi_square(3,3)
multi_square(11,2)
# Out:
# 10000
# 27
# 121

# %%
#abbitary arg

# %%
def number_arg(*pigs):
    print(pigs[0]*pigs[2])

# %%
number_arg(1,2,5, 5, 9, 12)
# Out:
# 5

# %%
#trying out some funtions

# %%
 def name(first_name, last_name):
     print('His fullname is'+ first_name+ "" + last_name)

# %%
name(' Faisal', ' Abdul')
name(' John', ' Max' )
# Out:
# His fullname is Faisal Abdul
# His fullname is John Max

# %%
#trails

# %%
def origin(country = 'Ghana'):
    print("i'm from" + country)

# %%
origin(' South Africa')
origin( ' Burkina Faso')
origin( ' Benin')
origin( ' Nigeria')
# Out:
# i'm from South Africa
# i'm from Burkina Faso
# i'm from Benin
# i'm from Nigeria

# %%
#trails

# %%
def factors(animal, name):
    print("my favorite pet is", animal)
    print("His", animal + "attibuties behavior like", name)

# %%
factors(animal=' eagle ', name=' Max')
# Out:
# my favorite pet is  eagle
# His  eagle attibuties behavior like  Max

# %%
def dress(dress_type, hair_type, shoe_type):
    print("she's outgoing hence dress", dress_type, 'attention wise', hair_type,'hair always and always on', shoe_type)

# %%
dress(dress_type = 'revealing dresses,', hair_type= 'long brazilian', shoe_type='long heels')
# Out:
# she's outgoing hence dress revealing dresses, attention wise long brazilian hair always and always on long heels

# %%
def vegetable_fruits(fruits):
    for fruit in fruits:
        print(fruit)

# %%
my_fruits = ['mango', 'avocado', 'cassava', 'ginger']
vegetable_fruits(my_fruits)
# Out:
# mango
# avocado
# cassava
# ginger

# %%
#key Word Argument

# %%
def multi_square(number,sqrt):
    print(number**sqrt)

# %%
multi_square(sqrt=10, number=4)
multi_square(number=3, sqrt=3)
# Out:
# 1048576
# 27

# %%
#customized functions()/key word argument

# %%
def number_kew(**number_arg):
    print('my lottery number is:' + number_arg['digit'] + 'my other lucky number is'+ number_arg['digit2'])

# %%
number_kew(digit = '33456', digit2 =' 67920')
# Out:
# my lottery number is:33456my other lucky number is 67920
