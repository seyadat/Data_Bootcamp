# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
#connecting to webstieabs

url = 'https://www.target.com/p/modular-bean-bag-section-sofa-armless-gray-room-essentials-8482/-/A-84720811#lnk=sametab'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

page= requests.get(url, headers = headers)

soup = BeautifulSoup(page.content, 'html.parser')

soup1= BeautifulSoup(soup.prettify(), 'html.parser')

Product_Title = soup1.find('div', {"data-module-type":"ProductDetailTitle"} ).get_text().strip()

Product_Price = soup1.find('div', {"data-module-type":"ProductDetailPrice"} ).get_text().strip()
if Product_Price:
    price = Product_Price.get_text(strip=True)
    print("Price:", price)
else:  
    price = "Price not found"
    print(price)


    print(ProductTitle)
    print(Product_Price)
# Out:
# Price not found
# Modular Bean Bag Section Sofa Armless Gray - Room Essentials™
# None

# %%
import datetime

today = datetime.date.today()
today
# Out:
# datetime.date(2025, 12, 8)

# %%
import csv 
header = ['Title', 'Current_Price', 'Date']
data = [Product_Title,Product_Price,today ]

with open('Amazon WebScrap.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
#improting the created file
import pandas as pd

df = pd.read_csv(r"C:\Users\Seyy_\Amazon WebScrap.csv")

df
# Out:
#                                                Title  Current_Price  \
# 0  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 1  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 2  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 3  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 4  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
#
#          Date
# 0  2025-12-08
# 1  2025-12-08
# 2  2025-12-08
# 3  2025-12-08
# 4  2025-12-08

# %%
#appending/adding data to the ccsv

with open('Amazon WebScrap.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#authomating

def check_price():

    url = 'https://www.target.com/p/modular-bean-bag-section-sofa-armless-gray-room-essentials-8482/-/A-84720811#lnk=sametab'
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
    }
    
    page= requests.get(url, headers = headers)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    
    soup1= BeautifulSoup(soup.prettify(), 'html.parser')
    
    Product_Title = soup1.find('div', {"data-module-type":"ProductDetailTitle"} ).get_text().strip()
    
    Product_Price = soup1.find('div', {"data-module-type":"ProductDetailPrice"} ).get_text().strip()
    if Product_Price:
        price = Product_Price.get_text(strip=True)
        print("Price:", price)
    else:
        price = "Price not found"
        print(price)

        import datetime

        today = datetime.date.today()

    import csv 
    header = ['Title', 'Current_Price', 'Date']
    data = [Product_Title,Product_Price,today ]

    with open('Amazon WebScrap.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

    #Automate to send a mail 
    if(price == 1):
        send_mail()

# %%
#AUTOMATION IN 10s
while (True):
    check_price()
    time.sleep(10)
# Out:
# Price not found
# Price not found
# Price not found
# Price not found
# Price not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 #AUTOMATION IN 10s
#       2 while (True):
# ----> 3     check_price()
#       4     time.sleep(10)
#
# Cell In[65], line 11, in check_price()
#       5 url = 'https://www.target.com/p/modular-bean-bag-section-sofa-armless-gray-room-essentials-8482/-/A-84720811#lnk=sametab'
#       7 headers = {
#       8     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
#       9 }
# ---> 11 page= requests.get(url, headers = headers)
#      13 soup = BeautifulSoup(page.content, 'html.parser')
#      15 soup1= BeautifulSoup(soup.prettify(), 'html.parser')
#
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Seyy_\Amazon WebScrap.csv")

df
# Out:
#                                                 Title  Current_Price  \
# 0   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 1   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 2   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 3   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 4   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 5   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 6   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 7   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 8   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 9   Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 10  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 11  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
# 12  Modular Bean Bag Section Sofa Armless Gray - R...            NaN
#
# ...

# %%
#Automating a mail sPending 
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    #server.starttis()
    server.ehlo()
    server.login('seyyadat#gmail.com','Pornstar@2')

    subject = 'the sofa you wanted price has now been limited'
    body = 'Mr, this is the moment to get it purchase. thank you'

    msg = f'Subject: {subject}\n\n{body}'

    server.sendmail(
        'seyyadat@gmail.com',
        msg
    )
